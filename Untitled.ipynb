# %%
import cv2
import dlib

import matplotlib.pyplot as plt

# %matplotlib notebook

def faceDetection(img,detector):
    return detector(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
detector = dlib.get_frontal_face_detector()

# %%
vc = cv2.VideoCapture(0)

plt.ion()

if vc.isOpened():
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    webcam_preview = plt.imshow(frame)    
else:
    is_capturing = False

while is_capturing:
    try:
        is_capturing, frame = vc.read()
        for k, d in enumerate(faceDetection(frame, detector)):
            cv2.rectangle(frame, (d.left(), d.top()), (d.right(), d.bottom()), (0, 0, 255), 1, 8, 0)
            
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
        
        webcam_preview.set_data(frame)
        plt.draw()

        try:
            plt.pause(0.05)
        except Exception:
            pass
    except KeyboardInterrupt:
        vc.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-c57cb4037473> in <module>()
#      13     try:
#      14         is_capturing, frame = vc.read()
# ---> 15         for k, d in enumerate(faceDetection(frame, detector)):
#      16             cv2.rectangle(frame, (d.left(), d.top()), (d.right(), d.bottom()), (0, 0, 255), 1, 8, 0)
#      17
#
# <ipython-input-1-b0cd9a2cbae2> in faceDetection(img, detector)
#       7
#       8 def faceDetection(img,detector):
# ----> 9     return detector(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:11079: error: (-215) scn == 3 || scn == 4 in function cvtColor
